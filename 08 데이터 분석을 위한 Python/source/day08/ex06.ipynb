# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("https://news.naver.com/").text
soup = bs(html, 'html.parser')
body = soup.select_one("body")
text = body.get_text().strip().replace("\n", " ")
stopwords = ['본문', '바로가기', 'NAVER'] # 불용어

text
# Out:
# '본문 바로가기        NAVER  뉴스   엔터     스포츠     날씨     프리미엄     대선           검색             언론사별 정치 경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 알고리즘 안내 정정보도 모음              콘텐츠   6.4(수)   전체 언론사 뉴스스탠드 라이브러리           언론사편집  기자                                                 연재                                                                  구독설정                                       속보     시진핑, 이재명에 축전 "수교 당시 초심 잊지 않길"    CJB청주방송       李대통령, 박성재 법무장관 외 나머지 국무위원 사의 반려    데일리안  내용작성전      이재명 대통령, 박성재 법무장관 외 국무위원 사의 반려    KBS  내용작성전      李대통령 \'1호 행정명령\' 비상경제점검 TF 구성 지시    서울경제  내용작성전      李대통령 \'1호 행정명령\' 비상경제점검 TF 구성 지시    중앙일보  내용작성전      李 대통령, 취임 후 첫 행정명령... 비상경제점검TF 구성 지시    조선비즈       李대통령 공약 ‘대법관 증원법’ 법사소위 통과…14명→ 30명    국제신문  내용작성전      이주호, 이 대통령에게 전체 국무위원 사의 표명    경향신문       李대통령 공약 ‘대법관 증원법’ 법사위 소위 통과…16명 늘려 30명    매경이코노미  내용작성전      이주호 총리 대행, 李대통령에 전체 국무위원 사의 표명    kbc광주방송       이주호 부총리, 이재명 대통령에게 전체 국무위원 사의 표명    부산일보      속보 닫기             부산일보 06월 04일 17:02  구독      스마트폰이 느려졌다면… \'재부팅\'이 답일까? [궁물받는다]    이 대통령 “통합·협치” 강조한 첫날, 여야 ‘입법 독주’ 신경전   시진핑 "이재명 대통령 당선 축하…한국은 중요한 이웃"   이전 문제 두고 갈등 빚던 건설폐기물 업체… 구청, 이전 허가 결정            서울경제 06월 04일 17:11  구독      “전쟁같은 정치 없길”…李, 정당 대표 등과 ‘비빔밥’ 오찬[이재명 시대]    [속보] 李대통령 \'1호 행정명령\' 비상경제점검 TF 구성 지시   국내외 코인 전문가 총집결…韓 가상자산 관심 후끈 [비트코인 서울 2025]   이재명·김문수는 1155억 받는데..\'이대남\' 몰표 이준석은 한 푼도 못 받는다            시사저널 06월 04일 17:10  구독      [속보] \'대법관 증원법\', 민주 주도로 법사소위 통과…16명 늘려 30명    민주 "김용태, 취임 첫날 거짓말로 헐뜯어…5일 선거법 등 처리 안 해"   李대통령 "한·일관계 실용적 관점 필요…협력할 건 협력, 정리할 건 정리"   李대통령 "당장 시행할 수 있는 경제회생책 필요…핵심은 추경"            조선비즈 06월 04일 17:06  구독      [이재명 시대] “검찰 세 조각 내겠다” 공약… 前 정권 의혹 수사에 나선 검찰    [속보] 李 대통령, 취임 후 첫 행정명령... 비상경제점검TF 구성 지시   李 “용산 와보니 무덤 같아… 韓日관계 실용적 관점 필요”   이주호, 이재명 대통령에게 
임, 가장 많이 말한 단어 \'성장\'…30조대 추경 기대    백악관, 이재명 대통령 당선 축하…"선거는 자유·공정, 중국 개입엔 여전한 우려"   PC 건너뛰고 스마트폰으로 직행한 인도…글로벌 3위 핀테크 시장 열어   파라다이스, 72억 규모 자사주 소각...“주주가치 제고”            KBS 06월 04일 17:06  구독      [속보] 이재명 대통령, 취임 후 첫 행정명령으로 ‘비상경제점검 TF 구성’ 지시    대통령실 인선안 발표…이 시각 용산 대통령실   ‘득표율 1%’ 발표되자 후원금 쇄도…“13억 원 모였다” [이런뉴스]   처자식 태우고 바다 돌진한 40대…“CCTV엔 젖은 채 ‘뚜벅뚜벅’” [지금뉴스]            한경비즈니스 06월 04일 15:09  구독      코스피 2760선 돌파... 새 정부 출범 기대감에 연고점 경신    이재명 정부 첫 인사…국무총리 김민석·비서실장 강훈식·국정원장 이종석   “지도부는 침묵 당은 분열” 국민의힘 패배 후폭풍 격화   [전문] 이재명 대통령 취임선서 후 "국민께 드리는 말씀"            뉴시스 06월 04일 17:10  구독      [단독]국민의힘 의원 단체방서 "김문수 당 대표" " ...

# %%
# konlpy : 한국어 형태소 분석기 
#!pip install konlpy

# %%
#!pip install jpype1

# %% [markdown]
# ### konlpy.tag.Okt
# - morphs : 테스트에서 형태소를 분리 반환
#
# > 형태소 : 의미를 가진 최소 단위

# %%
from konlpy.tag import Okt
okt = Okt(jvmpath="C:/Program Files/Java/jdk-21")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from konlpy.tag import Okt
# ----> 2 okt = Okt(jvmpath="C:/Program Files/Java/jdk-21")
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\konlpy\jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
#      65                             '-ea', '-Xmx{}m'.format(max_heap_size),
#      66                             classpath=classpath,
#      67                             convertStrings=True)
#      68 else:
#      69     raise ValueError("Please specify the JVM path.")
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\jpype\_core.py:286, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     280         jvmargs = _removeClassPath(jvmargs)
#     281     else:
#     282         # We are screwed no matter what we try or do.
#     283         # Unfortunately the jdk maintainers don't seem to care either.
#     284         # This bug is almost 10 years old and spans 16 jdk versions and counting.
#     285         # https://bugs.openjdk.org/browse/JDK-8079633?jql=text%20~%20%22ParseUtil%22
# --> 286         raise ValueError("jpype jar must be ascii to add to the system class path")
#     289 extra_jvm_args += ['-javaagent:' + supportLib]
#     291 try:
#
# ValueError: jpype jar must be ascii to add to the system class path

# %%
import os
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\admin\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_16052_YZMUFBQSPJCFRZQD',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-1CUBQGJ',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\admin',
#         'JAVA_HOME': 'C:\\Program Files\\Java\\jdk-21',
#         'JPY_INTERRUPT_EVENT': '1740',
#         'LOCALAPPDATA': 'C:\\Users\\admin\\AppData\\Local',
#         'LOGONSERVER': '\\\\DESKTOP-1CUBQGJ',
#         'NUMBER_OF_PROCESSORS': '16',
#         'ONEDRIVE': 'C:\\Users\\admin\\OneDrive',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\Users\\admin\\Desktop\\이용교\\08 데이터 분석을 위한 Python\\source\\basic\\Scripts;C:\\Users\\admin\\Desktop\\이용교\\08 데이터 분석을 위한 Python\\source\\basic\\Scripts;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files\\Bandizip\\;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\admin\\Desktop\\이용교\\gradle-8.14\\bin;C:\\Program Files\\nodejs\\;C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\admin\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\admin\\AppData\\Roaming\\npm',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 167 Stepping 1, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': 'a701',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(basic) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\Windows',
#         'TEMP': 'C:\\Users\\admin\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\admin\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'DESKTOP-1CUBQGJ',
#         'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-1CUBQGJ',
#         'USERNAME': 'admin',
#         'USERPROFILE': 'C:\\Users\\admin',
#         'VIRTUAL_ENV': 'C:\\Users\\admin\\Desktop\\이용교\\08 데이터 분석을 위한 Python\\source\\basic',
#         'VIRTUAL_ENV_PROMPT': '(basic) ',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\admin\\AppData\\Roaming\\Code\\CachedData\\258e40fedc6cb8edf399a463ce3a9d32e7e1f6f3',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code',
#         'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\39ba74c1-1.100.3-main-sock',
#         'VSCODE_L10N_BUNDLE_LOCATION': '',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"ko","resolvedLanguage":"en","defaultMessagesFile":"C:\\\\Users\\\\admin\\\\AppData\\\\Local\\\\Programs\\\\Microsoft VS Code\\\\resources\\\\app\\\\out\\\\nls.messages.json","locale":"en-us","availableLanguages":{}}',
#         'VSCODE_PID': '16052',
#         'WINDIR': 'C:\\Windows',
#         'ZES_ENABLE_SYSMAN': '1',
#         '_OLD_VIRTUAL_PATH': 'C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files\\Bandizip\\;C:\\Program Files\\Git\\cmd;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\Users\\admin\\Desktop\\이용교\\gradle-8.14\\bin;C:\\Program Files\\nodejs\\;C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\admin\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\admin\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\admin\\AppData\\Roaming\\npm',
#         '_OLD_VIRTUAL_PROMPT': '$P$G',
#         '__COMPAT_LAYER': 'DetectorsAppHealth',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}
