# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("https://news.naver.com/").text
soup = bs(html, 'html.parser')
body = soup.select_one("body")
text = body.get_text().strip().replace("\n", " ")
stopwords = ['본문', '바로가기', 'NAVER'] # 불용어

text
# Out:
# '본문 바로가기        NAVER  뉴스   엔터     스포츠     날씨     프리미엄     대선           검색             언론사별 정치 경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 알고리즘 안내 정정보도 모음              콘텐츠   6.5(목)   전체 언론사 뉴스스탠드 라이브러리           언론사편집  기자                                                 연재                                                                  구독설정                                       속보     \'임기 첫 날 몸싸움\' 李대통령 경호 경찰전담경호대 철수…경호처로 인계    한경비즈니스  내용작성전      李대통령 경호 경찰전담경호대 철수…경호처로 인계    중앙일보  내용작성전      홍준표 “국힘 뼛속까지 깊이 병들어…다가올 빙하기는 혹독한 시간될 것”    문화일보       이재명 대통령 경호 경찰전담경호대 철수… 경호처로 인계    국제신문  내용작성전      李대통령, 취임 후 첫 국무회의 주재…안전치안 점검회의도    강원도민일보       대전 카이스트 실험실서 한밤 중 폭발 화재…20대 女 중상    데일리안  내용작성전     속보 닫기             MBN 06월 05일 08:47  구독      이 대통령 "직급 무관하게 제안 달라"…경제TF서 \'전화번호\' 공개    "비상계엄 규명 작업 중인데"…윤 정부 지정기록물, \'깜깜이\' 논란   더불어민주당, 오늘 \'3대 특검법\' 본회의 처리 시도   바다로 돌진해 처자식 3명 살해한 40대 가장 구속            경기일보 06월 05일 08:44  구독      인천 서구 금곡동 교차로서 7중 추돌…2명 경상    전한길 "대선 패배, 이준석·한동훈 때문…尹 등에 칼 꽂아"   한낮 최고 30도 육박…큰 일교차 조심 [날씨]   이재명 대통령, 취임 후 첫 국무회의 주재            서울신문 06월 05일 08:38  구독      [속보] 1분기 GDP 0.2% 역성장… 국민소득 0.1%↑    남북관계 미련 없다는 北, 韓대선 이틀만 “리재명이…” 첫 보도는?   男아이돌에 성관계 영상 보낸 前여친 “다 올리겠다” 협박하다 결국   “젤렌스키, 카자흐 뚫고 ‘말벌’ 드론 쐈다” 푸틴 망신…한국은 괜찮나 [포착]            SBS Biz 06월 05일 08:35  구독      트럼프에 등 돌린 머스크 "감세법안 죽이자"    \'26조 규모\' 체코 원전 최종 계약…16년 만에 수주   美 보잉 대신 유럽 에어버스…"中, 최대 500대 주문 검토"   \'136만원 내면 비자 인터뷰 빨리 잡아줄게?\'…비자팔이 검토 美            한국경제TV 06월 05일 08:54  구독      \'26조원\' 최종계약 체결…16년만에 원전 수출    머스크 “예산안 폐기하라”…트럼프, 관세도 감세안도 꼬인다 [글로벌마켓 A/S]   이 지경까지 \'쯧쯧\'…"중국 보다 미국 싫어"   "이제는 비자장사까지"…인터뷰 신속 진행에 \'1천달러\' 급행료 검토            전자신문 06월 05일 07:30  구독      北 스마트폰의 섬뜩한 기능… “5분마다 화면 캡처해 전송”    머스크, 백악관 나가자마자… 트럼프 감
보다 보수화    달러 약세 지속…뉴욕시장 원-달러 환율 1359원까지 하락   [단독] 리박스쿨, 윤석열 취임 첫해부터 초등학교 접근 노렸다   [단독] 대선 직전 ‘리박스쿨’ 댓글 조작 정황 네이버에 포착            한겨레21 06월 05일 07:26  구독      점수, 1등, 위만 보던 ‘소도시 문제풀이 능력자’의 끝    가장 나쁜 싸움은 싸우지 않는 싸움   ‘대한민국’이 도망간 자리에 참전군인 류진성이 선 이유   ‘사이다’ 행정가에서 ‘내란 종식’ 대통령 되기까지…이재명이 걸어온 길            KBS 06월 05일 07:11  구독      이재명 대통령, 취임 후 첫 국무회의 주재…추경 논의·국정안정 당부    체코 원전 우여곡절 끝에 계약 성사…‘계약 무산’ 한 달만   크리켓 우승 축하하러 갔다가…인도서 인파 몰려 11명 압사   부모님이 매달 보내준 생활비…“세금 내라고요?” [잇슈 키워드]            머니투데이 06월 05일 08:12  구독      \'60세→65세\' 정년연장 힘받나…"청년 일자리 줄어" 갈등 해결 관건    "쑥쑥 크는 이 나라, 집에 냉장고·세탁기가 없네"…삼성·LG 공략 나섰다   "주부라 키울 능력 없잖아"…3살 딸 앞에서 아내 때린 남편, 양육권 주장   ...

# %%
# konlpy : 한국어 형태소 분석기 
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\admin\desktop\이용교\08 데이터 분석을 위한 python\source\basic\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\admin\desktop\이용교\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from konlpy) (1.5.1)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\admin\desktop\이용교\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\admin\desktop\이용교\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: packaging in c:\users\admin\desktop\이용교\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from JPype1>=0.7.0->konlpy) (25.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install jpype1

# %% [markdown]
# ### konlpy.tag.Okt
# - morphs : 테스트에서 형태소를 분리 반환
#
# > 형태소 : 의미를 가진 최소 단위

# %%
from konlpy.tag import Okt
okt = Okt()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from konlpy.tag import Okt
# ----> 2 okt = Okt()
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\konlpy\jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
#      65                             '-ea', '-Xmx{}m'.format(max_heap_size),
#      66                             classpath=classpath,
#      67                             convertStrings=True)
#      68 else:
#      69     raise ValueError("Please specify the JVM path.")
#
# File c:\Users\admin\Desktop\이용교\08 데이터 분석을 위한 Python\source\basic\Lib\site-packages\jpype\_core.py:286, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     280         jvmargs = _removeClassPath(jvmargs)
#     281     else:
#     282         # We are screwed no matter what we try or do.
#     283         # Unfortunately the jdk maintainers don't seem to care either.
#     284         # This bug is almost 10 years old and spans 16 jdk versions and counting.
#     285         # https://bugs.openjdk.org/browse/JDK-8079633?jql=text%20~%20%22ParseUtil%22
# --> 286         raise ValueError("jpype jar must be ascii to add to the system class path")
#     289 extra_jvm_args += ['-javaagent:' + supportLib]
#     291 try:
#
# ValueError: jpype jar must be ascii to add to the system class path
