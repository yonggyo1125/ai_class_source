# %%
import requests

# %%
response = requests.get("https://news.naver.com/section/105")

# %%
data = response.text.split('data-template-id="SECTION_HEADLINE">')[1]
data
# Out:
# '\n\t<div class="sa_head">\n\t\t<span class="sa_head_inner">\n\t\t\t<a href="#" class="sa_head_link _TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_l3qo5" data-clk="guide">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>\n\t\t</span>\n\t\t<div id="_SECTION_HEADLINE_INFO_l3qo5" class="sa_head_layer is_hidden">\n\t\t\t<p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>\n\t\t\t<a href="https://media.naver.com/algorithm" class="sa_head_layer_go">알고리즘 자세히 보기</a>\n\t\t\t<div class="sa_head_layer_close">\n\t\t\t\t<button type="button" class="_TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_l3qo5">닫기</button>\n\t\t\t</div>\n\t\t</div>\n\t</div>\n\t<ul id="_SECTION_HEADLINE_LIST_l3qo5" class="sa_list">\n\t\t<li class="sa_item _SECTION_HEADLINE">\n\t\t\t<div class="sa_item_inner">\n\t\t\t\t<div class="sa_item_flex _LAZY_LOADING_WRAP">\n\t\t\t\t\t<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">\n\t\t\t\t\t\t<div class="sa_thumb_inner">\n\t\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/009/0005502392" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005502392" data-imp-url="https://n.news.naver.com/mnews/article/009/0005502392" data-imp-index="1">\n\t\t\t\t\t\t\t\t<img data-src="https://mimgnews.pstatic.net/image/origin/009/2025/06/02/5502392.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="‘블루 아카이브’ 대한적십자사와 ‘세이빙 라이브스 투게더!’ 진행" style="display: none;">\n\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div class="sa_text">\n\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/009/0005502392" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000BC_000000000000000005502392" data-imp-url="https://n.news.naver.com/mnews/article/009/0005502392" data-imp-index="1">\n\t\t\t\t\t\t\t<strong class="sa_text_strong">‘블루 아카이브’ 대한적십자사와 ‘세이빙 라이브스 투게더!’ 진행</strong>\n\t\t\t\t\t\t</a>\n\t\t\t\t\t\t<div class="sa_text_lede">넥슨(공동 대표 강대현·김정욱)은 2일 서브컬처 게임 ‘블루 아카이브’가 대한적십자사와 함께 ‘세이빙 라이브스 투게더!(Saving Lives, Together!)’ 캠페인을 진행한다고 밝혔다. ‘세이빙 라이브스 투</div>\n\t\t\t\t\t\t<div class="sa_text_info">\n\t\t\t\t\t\t\t<div class="sa_text_info_left">\n\t\t\t\t\t\t\t\t<div class="sa_text_press">매일경제</div>\n\t\t\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/comment/009/0005502392" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news009,0005502392" data-zero-allow="false"></a>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\t<div class="sa_text_info_right">\n\t\t\t\t\t\t\t\t<a href="/cluster/c_202506021350_00000063/section/105?oid&#x3D;009&amp;aid&#x3D;0005502392" class="sa_text_cluster" data-clk="clcou">\n\t\t\t\t\t\t\t\t\t<span class="sa_text_cluster_num">6</span>\n\t\t\t\t\t\t\t\t\t<span class="blind">개의 관련뉴스 더보기</span>\n\t\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t</li>\n\t\t<li class="sa_item _SECTION_HEADLINE">\n\t\t\t<div class="sa_item_inner">\n\t\t\t\t<div class="sa_item_flex _LAZY_LOADING_WRAP">\n\t\t\t\t\t<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">\n\t\t\t\t\t\t<div class="sa_thumb_inner">\n\t\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/366/0001082197" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88127058_000000000000000001082197" data-imp-url="https://n.news.naver.com/mnews/article/366/0001082197" data-imp-index="2">\n\t\t\t\t\t\t\t\t<img data-src="https://mimgnews.pstatic.net/image/origin/366/2025/06/02/1082197.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="삼성전자, 퍼플렉시티에 투자… 구글 의존도 줄이고 AI OS 확대" style="display: none;">\n\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div class="sa_text">\n ...

# %%
data = data.split('sa_list">')[1]
data = data.split('\<\ul')[0]
data
# Out:
#   Cell In[31], line 2
#     data = data.split('\<\ul')[0]
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \uXXXX escape
