# %%
# !pip install tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow-hub in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-hub) (4.25.8)
# Requirement already satisfied: tf-keras>=2.14.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-hub) (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)

# %%
# !pip install tf-keras==2.17.0
# Out:
# Collecting tf-keras==2.17.0
#   Using cached tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorflow<2.18,>=2.17 (from tf-keras==2.17.0)
#   Using cached tensorflow-2.17.1-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.17.1 (from tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Using cached tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (1.73.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.10.0)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow<2.18,>=2.17->tf-keras==2.17.0) (0.1.2)
# Using cached tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.17.1-cp312-cp312-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl (382.4 MB)
# Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached protobuf-4.25.8-cp310-abi3-win_amd64.whl (413 kB)
# Using cached tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
# Installing collected packages: protobuf, numpy, tensorboard, ml-dtypes, tensorflow-intel, tensorflow, tf-keras
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 5.29.5
#
#     Uninstalling protobuf-5.29.5:
#
#       Successfully uninstalled protobuf-5.29.5
#
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#    ---------------------------------------- 0/7 [protobuf]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/7 [protobuf]
#    ----- ---------------------------------- 1/7 [numpy]
#     Found existing installation: numpy 2.1.3
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#     Uninstalling numpy-2.1.3:
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#   Attempting uninstall: tensorboard
#    ----- ---------------------------------- 1/7 [numpy]
#     Found existing installation: tensorboard 2.19.0
#    ----- ---------------------------------- 1/7 [numpy]
#    ----------- ---------------------------- 2/7 [tensorboard]
#     Uninstalling tensorboard-2.19.0:
#    ----------- ---------------------------- 2/7 [tensorboard]
#       Successfully uninstalled tensorboard-2.19.0
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------- ---------------------------- 2/7 [tensorboard]
#   Attempting uninstall: ml-dtypes
#    ----------- ---------------------------- 2/7 [tensorboard]
#     Found existing installation: ml_dtypes 0.5.1
#    ----------- ---------------------------- 2/7 [tensorboard]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#     Uninstalling ml_dtypes-0.5.1:
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#       Successfully uninstalled ml_dtypes-0.5.1
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ----------------- ---------------------- 3/7 [ml-dtypes]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#    ---------------------- ----------------- 4/7 [tensorflow-intel]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~l_dtypes'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'c:\\Users\\admin\\Desktop\\이용교\\09 핀테크 머신러닝과 딥러닝 이해\\source\\.venv\\Lib\\site-packages\\tensorflow\\compiler\\mlir\\lite\\python\\_pywrap_converter_api.pyd'
# Check the permissions.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.73.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorflow) (3.14.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: ml-dtypes, tensorboard
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml-dtypes 0.4.1
#
#     Uninstalling ml-dtypes-0.4.1:
#
#       Successfully uninstalled ml-dtypes-0.4.1
#
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#    ---------------------------------------- 0/2 [ml-dtypes]
#   Attempting uninstall: tensorboard
#    ---------------------------------------- 0/2 [ml-dtypes]
#    -------------------- ------------------- 1/2 [tensorboard]
#     Found existing installation: tensorboard 2.17.1
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#     Uninstalling tensorboard-2.17.1:
#    -------------------- ------------------- 1/2 [tensorboard]
#       Successfully uninstalled tensorboard-2.17.1
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    ---------------------------------------- 2/2 [tensorboard]
#
# Successfully installed ml-dtypes-0.5.1 tensorboard-2.19.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\~-_dtypes'.
#   You can safely remove it manually.

# %%
import tensorflow_hub as hub
import tf_keras as keras
# Out:
# Failed to import tensorflow. Please note that tensorflow is not installed by default when you install tensorflow_hub. This is so that users can decide which tensorflow package to use. To use tensorflow_hub, please install a current version of tensorflow by following the instructions at https://tensorflow.org/install and https://tensorflow.org/hub/installation.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import tensorflow_hub as hub
#       2 import tf_keras as keras
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow_hub\__init__.py:85
#      74   if (parse_version(tf.__version__) <
#      75       parse_version(required_tensorflow_version)):
#      76     raise ImportError(
#      77         "\n\nThis version of tensorflow_hub requires tensorflow "
#      78         "version >= {required}; Detected an installation of version {present}. "
#    (...)     82             required=required_tensorflow_version,
#      83             present=tf.__version__))
# ---> 85 _ensure_tf_install()
#      88 def _ensure_keras_2_importable():
#      89   """Check that Keras 2 can be used by attempting to import tf_keras.
#      90
#      91   Raises:
#      92     ImportError: if using tf.keras would mean using Keras 3 and tf_keras is not
#      93       installed.
#      94   """
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow_hub\__init__.py:49, in _ensure_tf_install()
#      42 """Attempt to import tensorflow, and ensure its version is sufficient.
#      43
#      44 Raises:
#      45   ImportError: if either tensorflow is not importable or its version is
#      46   inadequate.
#      47 """
#      48 try:
# ---> 49   import tensorflow as tf
#      50 except ImportError:
#      51   # Print more informative error message, then reraise.
#      52   print(
#      53       "\n\nFailed to import tensorflow. Please note that tensorflow is not "
#      54       "installed by default when you install tensorflow_hub. This is so that "
#    (...)     57       "by following the instructions at https://tensorflow.org/install and "
#      58       "https://tensorflow.org/hub/installation.\n\n")
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\__init__.py:53
#      51 from tensorflow._api.v2 import autograph
#      52 from tensorflow._api.v2 import bitwise
# ---> 53 from tensorflow._api.v2 import compat
#      54 from tensorflow._api.v2 import config
#      55 from tensorflow._api.v2 import data
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:32
#      30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
# ---> 32 from tensorflow._api.v2.compat.v1 import data
#      33 from tensorflow._api.v2.compat.v1 import debugging
#      34 from tensorflow._api.v2.compat.v1 import distribute
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\v1\data\__init__.py:8
#       3 """Public API for tf._api.v2.data namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.data import experimental
#       9 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE # line: 103
#      10 from tensorflow.python.data.ops.dataset_ops import DatasetV1 as Dataset # line: 3677
#
# File c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\_api\v2\compat\v1\data\experimental\__init__.py:32
#      30 from tensorflow.python.data.experimental.ops.interleave_ops import parallel_interleave # line: 29
#      31 from tensorflow.python.data.experimental.ops.interleave_ops import sample_from_datasets_v1 as sample_from_datasets # line: 158
# ---> 32 from tensorflow.python.data.experimental.ops.iterator_ops import get_model_proto # line: 103
#      33 from tensorflow.python.data.experimental.ops.iterator_ops import make_saveable_from_iterator # line: 41
#      34 from tensorflow.python.data.experimental.ops.lookup_ops import DatasetInitializer # line: 54
#
# ImportError: cannot import name 'get_model_proto' from 'tensorflow.python.data.experimental.ops.iterator_ops' (c:\Users\admin\Desktop\이용교\09 핀테크 머신러닝과 딥러닝 이해\source\.venv\Lib\site-packages\tensorflow\python\data\experimental\ops\iterator_ops.py)
